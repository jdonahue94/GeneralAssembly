# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Jonat\dat-02-22\ClassMaterial\Unit2\data\master.csv", parse_dates=['visit_date', 'calendar_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252108 entries, 0 to 252107
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                252108 non-null  object
#  1   visit_date        252108 non-null  datetime64[ns]
#  2   visitors          252108 non-null  int64
#  3   calendar_date     252108 non-null  datetime64[ns]
#  4   day_of_week       252108 non-null  object
#  5   holiday           252108 non-null  int64
#  6   genre             252108 non-null  object
#  7   area              252108 non-null  object
#  8   latitude          252108 non-null  float64
#  9   longitude         252108 non-null  float64
#  10  reserve_visitors  108394 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(4)
# memory usage: 21.2+ MB

# %%
df.describe()
# Out:
#             visitors        holiday       latitude      longitude  \
# count  252108.000000  252108.000000  252108.000000  252108.000000
# mean       20.973761       0.050673      35.613121     137.357865
# std        16.757007       0.219329       2.044473       3.671577
# min         1.000000       0.000000      33.211967     130.195555
# 25%         9.000000       0.000000      34.692337     135.341564
# 50%        17.000000       0.000000      35.658068     139.670038
# 75%        29.000000       0.000000      35.694003     139.751599
# max       877.000000       1.000000      44.020632     144.273398
#
#        reserve_visitors
# count     108394.000000
# mean          16.699808
# std           17.388735
# min            1.000000
# 25%            4.000000
# 50%           10.000000
# 75%           24.000000
# max           96.000000

# %%
df['visitors']
# Out:
# 20.973761245180636

# %%
df['visitors'].std()
# Out:
# 16.757007314183262

# %%
df[:50]
# Out:
#                       id visit_date  visitors calendar_date day_of_week  \
# 0   air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday
# 1   air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday
# 2   air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday
# 3   air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday
# 4   air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday
# 5   air_ba937bf13d40fb24 2016-01-19         9    2016-01-19     Tuesday
# 6   air_ba937bf13d40fb24 2016-01-20        31    2016-01-20   Wednesday
# 7   air_ba937bf13d40fb24 2016-01-21        21    2016-01-21    Thursday
# 8   air_ba937bf13d40fb24 2016-01-22        18    2016-01-22      Friday
# 9   air_ba937bf13d40fb24 2016-01-23        26    2016-01-23    Saturday
# 10  air_ba937bf13d40fb24 2016-01-25        21    2016-01-25      Monday
# 11  air_ba937bf13d40fb24 2016-01-26        11    2016-01-26     Tuesday
# ...

# %%
df['visitors'][:50].sum()
# Out:
# 1039

# %%
df.iloc[:, -3:]
# Out:
#          latitude   longitude  reserve_visitors
# 0       35.658068  139.751599               NaN
# 1       35.658068  139.751599               NaN
# 2       35.658068  139.751599               NaN
# 3       35.658068  139.751599               NaN
# 4       35.658068  139.751599               NaN
# ...           ...         ...               ...
# 252103  34.695124  135.197852               6.0
# 252104  34.695124  135.197852              37.0
# 252105  34.695124  135.197852              35.0
# 252106  34.695124  135.197852               3.0
# 252107  34.695124  135.197852              32.0
#
# [252108 rows x 3 columns]

# %%
df = df.set_index('visit_date')

# %%
df.head()
# Out:
#                               id  visitors calendar_date day_of_week  holiday  \
# visit_date
# 2016-01-13  air_ba937bf13d40fb24        25    2016-01-13   Wednesday        0
# 2016-01-14  air_ba937bf13d40fb24        32    2016-01-14    Thursday        0
# 2016-01-15  air_ba937bf13d40fb24        29    2016-01-15      Friday        0
# 2016-01-16  air_ba937bf13d40fb24        22    2016-01-16    Saturday        0
# 2016-01-18  air_ba937bf13d40fb24         6    2016-01-18      Monday        0
#
#                  genre                          area   latitude   longitude  \
# visit_date
# 2016-01-13  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 2016-01-14  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 2016-01-15  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 2016-01-16  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 2016-01-18  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
#
# ...

# %%
df.loc['2016-01-13':'2018-01-13', ['calendar_date', 'day_of_week']]
# Out:
#            calendar_date day_of_week
# visit_date
# 2016-01-13    2016-01-13   Wednesday
# 2016-01-14    2016-01-14    Thursday
# 2016-01-15    2016-01-15      Friday
# 2016-01-16    2016-01-16    Saturday
# 2016-01-18    2016-01-18      Monday
# ...                  ...         ...
# 2017-04-21    2017-04-21      Friday
# 2017-04-22    2017-04-22    Saturday
# 2017-03-26    2017-03-26      Sunday
# 2017-03-20    2017-03-20      Monday
# 2017-04-09    2017-04-09      Sunday
#
# [249776 rows x 2 columns]

# %%
df['visitors'][:100].mean()
# Out:
# 23.1

# %%
df['visitors'].mean()
# Out:
# 20.973761245180636

# %%
df[['visitors', 'holiday']].median()
# Out:
# visitors    17.0
# holiday      0.0
# dtype: float64

# %%
df['visitors'][:5000].min()
# Out:
# 1

# %%
df.iloc[:, -4:].mode()
# Out:
#                              area   latitude   longitude  reserve_visitors
# 0  Fukuoka-ken Fukuoka-shi Daimyō  33.589216  130.392813               2.0

# %%
df.iloc[:250, :3].mean()
# Out:
# visitors    24.912
# dtype: float64

# %%
df.describe()
# Out:
#             visitors        holiday       latitude      longitude  \
# count  252108.000000  252108.000000  252108.000000  252108.000000
# mean       20.973761       0.050673      35.613121     137.357865
# std        16.757007       0.219329       2.044473       3.671577
# min         1.000000       0.000000      33.211967     130.195555
# 25%         9.000000       0.000000      34.692337     135.341564
# 50%        17.000000       0.000000      35.658068     139.670038
# 75%        29.000000       0.000000      35.694003     139.751599
# max       877.000000       1.000000      44.020632     144.273398
#
#        reserve_visitors
# count     108394.000000
# mean          16.699808
# std           17.388735
# min            1.000000
# 25%            4.000000
# 50%           10.000000
# 75%           24.000000
# max           96.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 252108 entries, 2016-01-13 to 2017-04-09
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                252108 non-null  object
#  1   visitors          252108 non-null  int64
#  2   calendar_date     252108 non-null  datetime64[ns]
#  3   day_of_week       252108 non-null  object
#  4   holiday           252108 non-null  int64
#  5   genre             252108 non-null  object
#  6   area              252108 non-null  object
#  7   latitude          252108 non-null  float64
#  8   longitude         252108 non-null  float64
#  9   reserve_visitors  108394 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(4)
# memory usage: 26.2+ MB

# %%
df[df['visitors'] > 30]
# Out:
#                               id  visitors calendar_date day_of_week  holiday  \
# visit_date
# 2016-01-14  air_ba937bf13d40fb24        32    2016-01-14    Thursday        0
# 2016-01-20  air_ba937bf13d40fb24        31    2016-01-20   Wednesday        0
# 2016-02-05  air_ba937bf13d40fb24        45    2016-02-05      Friday        0
# 2016-02-10  air_ba937bf13d40fb24        32    2016-02-10   Wednesday        0
# 2016-02-19  air_ba937bf13d40fb24        43    2016-02-19      Friday        0
# ...                          ...       ...           ...         ...      ...
# 2017-04-15  air_a17f0778617c76e2        61    2017-04-15    Saturday        0
# 2017-04-21  air_a17f0778617c76e2        49    2017-04-21      Friday        0
# 2017-04-22  air_a17f0778617c76e2        60    2017-04-22    Saturday        0
# 2017-03-26  air_a17f0778617c76e2        69    2017-03-26      Sunday        0
# 2017-03-20  air_a17f0778617c76e2        31    2017-03-20      Monday        1
#
# ...

# %%
df = df.reset_index()

# %%
df[(df['visit_date'] < '2018-01-01') & (df['day_of_week'] == 'Wednesday')].iloc[:50, :3].mean()
# Out:
# visitors    25.3
# dtype: float64

# %%
df[(df['day_of_week'] == 'Sunday') | (df['day_of_week'] == 'Saturday')]['visitors'].mean()
# Out:
# 25.256869738495084

# %%
df[df['holiday'] == 0]['visitors'].mean()
# Out:
# 20.828063827386945

# %%
df[df['genre'] == 'Dining bar']['visitors'].max()
# Out:
# 348

# %%
df[df['holiday'] == 1]['visitors'].idxmax()
# Out:
# 122871

# %%
df.iloc[122871]
# Out:
# visit_date                              2016-12-30 00:00:00
# id                                     air_df554c4527a1cfe6
# visitors                                                205
# calendar_date                           2016-12-30 00:00:00
# day_of_week                                          Friday
# holiday                                                   1
# genre                                               Izakaya
# area                Shizuoka-ken Hamamatsu-shi Motoshirochō
# latitude                                            34.7109
# longitude                                           137.726
# reserve_visitors                                         58
# Name: 122871, dtype: object
