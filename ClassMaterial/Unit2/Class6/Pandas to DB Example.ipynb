# %% [markdown]
# ### Connecting Pandas to a Database
#
# This notebook will walk us through how to use pandas to interact with a database, and then query an API and add new values to it.
#
# Running this code continuously will allow us to programmatically collect a unique data source.

# %%
import pandas as pd
import numpy as np
# you will need to import this -- pip install SQLAlchemy
from sqlalchemy import create_engine, types
# you will need to import this -- pip install mysql-connector-python
import mysql.connector
import requests
# you will need to install this  -- pip install requests-oauthlib
from requests_oauthlib import OAuth1

# %% [markdown]
# ### Step 1:  Fetching the Data From the Database

# %%
# we'll create a dictionary to store all of our database information
df_dict = {
    'connector': 'mysql+mysqlconnector',
    'username' : 'dat1019',
    'password' : 'dat1019password',
    'server'   : 'dat-10-19.cfvn8ddij95j.us-east-1.rds.amazonaws.com',
    'port'     : '3306',
    'database' : 'dat1019'
}

# %%
df_dict['connector']
# Out:
# 'mysql+mysqlconnector'

# %%
# this string contains all the information
connection_string = f"{df_dict['connector']}://{df_dict['username']}:{df_dict['password']}@{df_dict['server']}:{df_dict['port']}/{df_dict['database']}"

# %%
connection_string
# Out:
# 'mysql+mysqlconnector://dat1019:dat1019password@dat-10-19.cfvn8ddij95j.us-east-1.rds.amazonaws.com:3306/dat1019'

# %%
# this is what we need to connect to our database
engine = create_engine(connection_string)

# %%
# we'll now connect to the database and pull in the info
with engine.connect() as connection:
    tweets = pd.read_sql_query("SELECT * FROM tweets", con=connection)

# %%
# let's look at our results
tweets.head()
# Out:
#               name      screen_name  \
# 0  Donald J. Trump  realDonaldTrump
# 1  Donald J. Trump  realDonaldTrump
# 2  Donald J. Trump  realDonaldTrump
# 3  Donald J. Trump  realDonaldTrump
# 4  Donald J. Trump  realDonaldTrump
#
#                                                 text  retweets  favorites  \
# 0  RT @realDonaldTrump: VOTE! VOTE! VOTE!\nhttps:...    117124          0
# 1                            https://t.co/zX4bqgtWqH     10186      47177
# 2                            https://t.co/SMaOF79kPV     10806      44040
# 3  RT @BarstoolNewsN: The Amish are not playing a...     17887          0
# 4  A parade for me in Nigeria, a great honor! htt...     39398     199959
#
#                     id
# 0  1323692146147340299
# 1  1323692020880297986
# 2  1323691984989622272
# 3  1323684790894297089
# 4  1323680963310866435

# %%
# we will turn this column into a string -- useful for later processing
tweets['id'] = tweets.id.astype(str)

# %% [markdown]
# ### Step 2:  Getting API Data

# %%
# authorization information for the Twitter API
tokens = OAuth1('NOZHm1aLT1AVmchGbCmiZOAga', 'nPyaYCt8L7ymqGZtU8EqC0a2ypI9aSJgVNIhtoZ0wGsaf3BJw9',
                '1079981876864008192-AlhO4yOa06oW2sXZpLpWPwnOxEERYS', 'o3E0AsKJfDoTBk77UQYExzOG7E46jPYvpWNGAKsD6lUBY')

# %%
# the api endpoint we'll ping to get our API results
base_url = 'https://api.twitter.com/1.1/statuses/user_timeline.json?screen_name=JoeBiden&count=200'

# %%
# this is our list of dictionaries that contains Donald Trump's tweets
tweet_results = requests.get(base_url, auth=tokens).json()

# %%
# here's our resulting dictionary
tweet_results[0]
# Out:
# {'created_at': 'Wed Mar 10 20:37:40 +0000 2021',
#  'id': 1369749317628661760,
#  'id_str': '1369749317628661760',
#  'text': 'RT @WhiteHouse: From $1,400 checks and unemployment relief to vaccines for every American — help is here. https://t.co/R0AYaTbkTV',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'WhiteHouse',
#     'name': 'The White House',
#     'id': 1323730225067339784,
#     'id_str': '1323730225067339784',
#     'indices': [3, 14]}],
#   'urls': [],
#   'media': [{'id': 1369738836176166913,
#     'id_str': '1369738836176166913',
#     'indices': [106, 129],
#     'media_url': 'http://pbs.twimg.com/media/EwJKRhXXIAAMnwp.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/EwJKRhXXIAAMnwp.jpg',
#     'url': 'https://t.co/R0AYaTbkTV',
#     'display_url': 'pic.twitter.com/R0AYaTbkTV',
#     'expanded_url': 'https://twitter.com/WhiteHouse/status/1369738906925694979/video/1',
#     'type': 'photo',
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#      'medium': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#      'large': {'w': 1080, 'h': 1080, 'resize': 'fit'}},
#     'source_status_id': 1369738906925694979,
#     'source_status_id_str': '1369738906925694979',
#     'source_user_id': 1323730225067339784,
#     'source_user_id_str': '1323730225067339784'}]},
#  'extended_entities': {'media': [{'id': 1369738836176166913,
#     'id_str': '1369738836176166913',
#     'indices': [106, 129],
#     'media_url': 'http://pbs.twimg.com/media/EwJKRhXXIAAMnwp.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/EwJKRhXXIAAMnwp.jpg',
#     'url': 'https://t.co/R0AYaTbkTV',
#     'display_url': 'pic.twitter.com/R0AYaTbkTV',
#     'expanded_url': 'https://twitter.com/WhiteHouse/status/1369738906925694979/video/1',
#     'type': 'video',
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#      'medium': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#      'large': {'w': 1080, 'h': 1080, 'resize': 'fit'}},
#     'source_status_id': 1369738906925694979,
#     'source_status_id_str': '1369738906925694979',
#     'source_user_id': 1323730225067339784,
#     'source_user_id_str': '1323730225067339784',
#     'video_info': {'aspect_ratio': [1, 1],
#      'duration_millis': 38413,
#      'variants': [{'bitrate': 832000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/amplify_video/1369738836176166913/vid/540x540/EIpkcX8dybDDUe1a.mp4?tag=14'},
#       {'bitrate': 1280000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/amplify_video/1369738836176166913/vid/720x720/4CN2GdCiJRkWwtw2.mp4?tag=14'},
#       {'content_type': 'application/x-mpegURL',
#        'url': 'https://video.twimg.com/amplify_video/1369738836176166913/pl/V7PM19ya955wG04u.m3u8?tag=14'},
#       {'bitrate': 432000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/amplify_video/1369738836176166913/vid/320x320/HzBS0E3SPZYY-I3k.mp4?tag=14'}]},
#     'additional_media_info': {'title': '',
#      'description': '',
#      'monetizable': False,
#      'source_user': {'id': 1323730225067339784,
#       'id_str': '1323730225067339784',
#       'name': 'The White House',
#       'screen_name': 'WhiteHouse',
#       'location': 'United States of America',
#       'description': 'Welcome to the Biden-Harris White House! Tweets may be archived: https://t.co/IURuMIrzxb',
#       'url': 'https://t.co/IxLjEB2zlE',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/IxLjEB2zlE',
#           'expanded_url': 'http://WhiteHouse.gov',
#           'display_url': 'WhiteHouse.gov',
#           'indices': [0, 23]}]},
#        'description': {'urls': [{'url': 'https://t.co/IURuMIrzxb',
#           'expanded_url': 'http://whitehouse.gov/privacy',
#           'display_url': 'whitehouse.gov/privacy',
#           'indices': [65, 88]}]}},
#       'protected': False,
#       'followers_count': 4944795,
#       'friends_count': 5,
#       'listed_count': 7737,
#       'created_at': 'Tue Nov 03 20:55:58 +0000 2020',
#       'favourites_count': 0,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': True,
#       'statuses_count': 624,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F5F8FA',
#       'profile_background_image_url': None,
#       'profile_background_image_url_https': None,
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1351938473142448133/JQT93Cjo_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1351938473142448133/JQT93Cjo_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1323730225067339784/1614726233',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': True,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'}}}]},
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 939091,
#   'id_str': '939091',
#   'name': 'Joe Biden',
#   'screen_name': 'JoeBiden',
#   'location': 'Wilmington, DE',
#   'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.',
#   'url': 'https://t.co/UClrPuJpyZ',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ',
#       'expanded_url': 'http://joebiden.com',
#       'display_url': 'joebiden.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 29297661,
#   'friends_count': 47,
#   'listed_count': 35366,
#   'created_at': 'Sun Mar 11 17:51:24 +0000 2007',
#   'favourites_count': 20,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 7236,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '565959',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/939091/1604514209',
#   'profile_link_color': '233F94',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'EBEBFF',
#   'profile_text_color': '323232',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Wed Mar 10 19:56:18 +0000 2021',
#   'id': 1369738906925694979,
#   'id_str': '1369738906925694979',
#   'text': 'From $1,400 checks and unemployment relief to vaccines for every American — help is here. https://t.co/R0AYaTbkTV',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1369738836176166913,
#      'id_str': '1369738836176166913',
#      'indices': [90, 113],
#      'media_url': 'http://pbs.twimg.com/media/EwJKRhXXIAAMnwp.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EwJKRhXXIAAMnwp.jpg',
#      'url': 'https://t.co/R0AYaTbkTV',
#      'display_url': 'pic.twitter.com/R0AYaTbkTV',
#      'expanded_url': 'https://twitter.com/WhiteHouse/status/1369738906925694979/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#       'large': {'w': 1080, 'h': 1080, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1369738836176166913,
#      'id_str': '1369738836176166913',
#      'indices': [90, 113],
#      'media_url': 'http://pbs.twimg.com/media/EwJKRhXXIAAMnwp.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EwJKRhXXIAAMnwp.jpg',
#      'url': 'https://t.co/R0AYaTbkTV',
#      'display_url': 'pic.twitter.com/R0AYaTbkTV',
#      'expanded_url': 'https://twitter.com/WhiteHouse/status/1369738906925694979/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#       'large': {'w': 1080, 'h': 1080, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [1, 1],
#       'duration_millis': 38413,
#       'variants': [{'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1369738836176166913/vid/540x540/EIpkcX8dybDDUe1a.mp4?tag=14'},
#        {'bitrate': 1280000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1369738836176166913/vid/720x720/4CN2GdCiJRkWwtw2.mp4?tag=14'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/amplify_video/1369738836176166913/pl/V7PM19ya955wG04u.m3u8?tag=14'},
#        {'bitrate': 432000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1369738836176166913/vid/320x320/HzBS0E3SPZYY-I3k.mp4?tag=14'}]},
#      'additional_media_info': {'title': '',
#       'description': '',
#       'monetizable': False}}]},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">The White House</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1323730225067339784,
#    'id_str': '1323730225067339784',
#    'name': 'The White House',
#    'screen_name': 'WhiteHouse',
#    'location': 'United States of America',
#    'description': 'Welcome to the Biden-Harris White House! Tweets may be archived: https://t.co/IURuMIrzxb',
#    'url': 'https://t.co/IxLjEB2zlE',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/IxLjEB2zlE',
#        'expanded_url': 'http://WhiteHouse.gov',
#        'display_url': 'WhiteHouse.gov',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/IURuMIrzxb',
#        'expanded_url': 'http://whitehouse.gov/privacy',
#        'display_url': 'whitehouse.gov/privacy',
#        'indices': [65, 88]}]}},
#    'protected': False,
#    'followers_count': 4944795,
#    'friends_count': 5,
#    'listed_count': 7737,
#    'created_at': 'Tue Nov 03 20:55:58 +0000 2020',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 624,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1351938473142448133/JQT93Cjo_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1351938473142448133/JQT93Cjo_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1323730225067339784/1614726233',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1977,
#   'favorite_count': 10894,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'is_quote_status': False,
#  'retweet_count': 1977,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'en'}

# %%
# we'll take our results and turn them into a dataframe
results = pd.DataFrame({
    'name': [result['user']['name'] for result in tweet_results],
    'screen_name': [result['user']['screen_name'] for result in tweet_results],
    'text': [result['text'] for result in tweet_results],
    'retweets': [result['retweet_count'] for result in tweet_results],
    'favorites': [result['favorite_count'] for result in tweet_results],
    'id': [result['id_str'] for result in tweet_results]
})

print(f"API call brought in {results.shape[0]} new tweets")
results.head()
# Out:
# API call brought in 200 new tweets
#         name screen_name                                               text  \
# 0  Joe Biden    JoeBiden  RT @WhiteHouse: From $1,400 checks and unemplo...
# 1  Joe Biden    JoeBiden   RT @POTUS: Help is here. https://t.co/urZCiigeS1
# 2  Joe Biden    JoeBiden  RT @POTUS: Keep the faith, folks. We will get ...
# 3  Joe Biden    JoeBiden  RT @POTUS: I want every child to know that thi...
# 4  Joe Biden    JoeBiden  RT @POTUS: I believe every worker deserves a f...
#
#    retweets  favorites                   id
# 0      1977          0  1369749317628661760
# 1      7782          0  1369739522263617539
# 2      4795          0  1369666671380692994
# 3     28424          0  1369400644382101510
# 4      7247          0  1369356116795285511

# %% [markdown]
# ### Step 3:  Checking For New Values

# %%
# this does a check for new values
# left merge means 'tweets' is the dominant table
# indicator lets you know if the value was present in one of the tables or both
results.merge(tweets, on='id', how='left', indicator=True)
# Out:
#               name_x    screen_name_x  \
# 0    Donald J. Trump  realDonaldTrump
# 1    Donald J. Trump  realDonaldTrump
# 2    Donald J. Trump  realDonaldTrump
# 3    Donald J. Trump  realDonaldTrump
# 4    Donald J. Trump  realDonaldTrump
# ..               ...              ...
# 195  Donald J. Trump  realDonaldTrump
# 196  Donald J. Trump  realDonaldTrump
# 197  Donald J. Trump  realDonaldTrump
# 198  Donald J. Trump  realDonaldTrump
# 199  Donald J. Trump  realDonaldTrump
#
#                                                 text_x  retweets_x  \
# 0    Congratulations, the Moderna vaccine is now av...        8334
# 1                              https://t.co/oMa4GS9q6K       37037
# 2    THANK YOU to the GREAT men and women of @FedEx...       31455
# 3    The Secretary of State and Governor of Georgia...       43659
# 4    Governor @BrianKempGA of Georgia still has not...       39110
# ..                                                 ...         ...
# 195  RT @WhiteHouse: "The plan we put forward prior...        9328
# 196  RT @WhiteHouse: "If authorized, tens of millio...        9008
# 197  RT @WhiteHouse: Before Operation Warp Speed, t...        7096
# 198  RT @WhiteHouse: "From the instant the Coronavi...        8161
# 199  RT @WhiteHouse: LIVE: Operation Warp Speed Vac...        8194
#
#      favorites_x                   id           name_y    screen_name_y  \
# 0          55602  1340096386113687554  Donald J. Trump  realDonaldTrump
# 1         126120  1339993708146683905  Donald J. Trump  realDonaldTrump
# 2         211238  1339971240157736960  Donald J. Trump  realDonaldTrump
# 3         150579  1339953001847525379  Donald J. Trump  realDonaldTrump
# 4         167805  1339938332223139840  Donald J. Trump  realDonaldTrump
# ..           ...                  ...              ...              ...
# 195            0  1336415114191400966  Donald J. Trump  realDonaldTrump
# 196            0  1336415090770399236  Donald J. Trump  realDonaldTrump
# 197            0  1336415057601761282  Donald J. Trump  realDonaldTrump
# 198            0  1336415036210864130  Donald J. Trump  realDonaldTrump
# 199            0  1336411597330391046  Donald J. Trump  realDonaldTrump
#
#                                                 text_y  retweets_y  \
# 0    Congratulations, the Moderna vaccine is now av...        5274
# 1                              https://t.co/oMa4GS9q6K        2211
# 2    THANK YOU to the GREAT men and women of @FedEx...        9451
# 3    The Secretary of State and Governor of Georgia...       15029
# 4    Governor @BrianKempGA of Georgia still has not...       12539
# ..                                                 ...         ...
# 195  RT @WhiteHouse: "The plan we put forward prior...         882
# 196  RT @WhiteHouse: "If authorized, tens of millio...         996
# 197  RT @WhiteHouse: Before Operation Warp Speed, t...         704
# 198  RT @WhiteHouse: "From the instant the Coronavi...        1095
# 199  RT @WhiteHouse: LIVE: Operation Warp Speed Vac...        2715
#
#      favorites_y _merge
# 0          32019   both
# 1           6485   both
# 2          56821   both
# 3          51065   both
# 4          50669   both
# ..           ...    ...
# 195            0   both
# 196            0   both
# 197            0   both
# 198            0   both
# 199            0   both
#
# [200 rows x 12 columns]

# %%
# we'll save the variable
merged_df = results.merge(tweets, on='id', how='left', indicator=True)

# %%
# select the values that are left_only in the _merge column -- these are new values
print(f"Found {merged_df[merged_df._merge == 'left_only'].shape[0]} new tweets not currently in the database")
merged_df[merged_df._merge == 'left_only']
# Out:
# Found 0 new tweets not currently in the database
# Empty DataFrame
# Columns: [name_x, screen_name_x, text_x, retweets_x, favorites_x, id, name_y, screen_name_y, text_y, retweets_y, favorites_y, _merge]
# Index: []

# %%
# get the index positions where this value is True
merged_df[merged_df._merge == 'left_only'].index
# Out:
# Int64Index([], dtype='int64')

# %%
results.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
# use these values to look up tweets in the original results df
idx = merged_df[merged_df._merge == 'left_only'].index
# and these are our new tweets
results.iloc[idx]
# Out:
#               name      screen_name  \
# 0  Donald J. Trump  realDonaldTrump
# 1  Donald J. Trump  realDonaldTrump
# 2  Donald J. Trump  realDonaldTrump
# 3  Donald J. Trump  realDonaldTrump
# 4  Donald J. Trump  realDonaldTrump
# 5  Donald J. Trump  realDonaldTrump
#
#                                                 text  retweets  favorites  \
# 0  RT @realDonaldTrump: VOTE! VOTE! VOTE!\nhttps:...    121165          0
# 1  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...     14850          0
# 2  RT @realDonaldTrump: https://t.co/gsFSgh2KPc h...     11699          0
# 3  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...     11580          0
# 4       RT @realDonaldTrump: https://t.co/voxNnIYMpe      8901          0
# 5  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...     13069          0
#
#                     id
# 0  1323714481353068546
# 1  1323714393184653323
# 2  1323714331922583556
# 3  1323714155967373312
# 4  1323714095225384962
# 5  1323713956280754182

# %%
# and now we'll connect to the database and add in the values
with engine.connect() as connection:
    # declare data types for the db -- not necessary but a useful step if you are doing this the first time
    dtypes = {
        'name': types.String(length=65535),
        'screen_name': types.String(length=65535),
        'text': types.String(length=65535),
        'retweets': types.Integer(),
        'favorites': types.Integer(),
        'id': types.String(length=65535)
    }
    print("Adding values to database")
    try:
        results.iloc[idx].to_sql('tweets', con=connection, index=False, if_exists='append', dtype=dtypes)
        print("Successful")
    except Exception as e:
        print("Could not add results to the database.", e)
# Out:
# Adding values to database
# Successful
